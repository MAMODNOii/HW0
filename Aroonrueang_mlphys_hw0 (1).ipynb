# %% [markdown]
# ### 6370219723 Karnchana Aroonrueang

# %% [markdown]
# # 0. Just importing used modules/libralies

# %%
import numpy as np
# %matplotlib inline
from sklearn import datasets, linear_model
from sklearn.preprocessing import PolynomialFeatures
from matplotlib import pyplot as plt, rcParams

# %% [markdown]
# # 1. Fitting vs. predicting when the data is in the model class

# %% [markdown]
# ## 1.1 $f(x)=2x$, $N_{\mathrm{train}}=10$, $\sigma=0$

# %%
################# Training the Model #################

# The Training Data
N_train=10
sigma_train=0;
x=np.linspace(0,1,N_train)
s = sigma_train*np.random.randn(N_train)
y=2*x+s #linear
fig = plt.figure(figsize=(8, 6))
p1=plt.plot(x, y, "o", ms=8, alpha=0.5, label='Training')

# Linear Regression
clf = linear_model.LinearRegression()
clf.fit(x[:, np.newaxis], y)
xplot=np.linspace(-0.02,1.02,200) # grid of points, some are in the training set, some are not
linear_plot=plt.plot(xplot, clf.predict(xplot[:, np.newaxis]), label='Linear')

# 3rd-order polynomial Regression
poly3 = PolynomialFeatures(degree=3)
X = poly3.fit_transform(x[:,np.newaxis])
clf3 = linear_model.LinearRegression()
clf3.fit(X,y)
Xplot=poly3.fit_transform(xplot[:,np.newaxis])
poly3_plot=plt.plot(xplot, clf3.predict(Xplot), label='Poly 3')

# 10th-order polynomial Regression
poly10 = PolynomialFeatures(degree=10)
X = poly10.fit_transform(x[:,np.newaxis])
clf10 = linear_model.LinearRegression()
clf10.fit(X,y)
Xplot=poly10.fit_transform(xplot[:,np.newaxis])
poly10_plot=plt.plot(xplot, clf10.predict(Xplot), label='Poly 10')

plt.legend(loc='best')
plt.ylim([-7,7])
plt.xlabel("x")
plt.ylabel("y")
Title="N=%i, $\sigma=%.2f$"%(N_train,sigma_train)
plt.title(Title+" (train)")

plt.grid()
plt.show()



################# Testing the Fitted Model #################

# The testing data
N_test=20
sigma_test=sigma_train
max_x=1.2
x_test=max_x*np.random.random(N_test)
s_test = sigma_test*np.random.randn(N_test)
y_test=2*x_test+s_test #Linear

# Make design matrices for prediction : Linear, 3rd and 10th
x_plot=np.linspace(0,max_x, 200)
X3 = poly3.fit_transform(x_plot[:,np.newaxis])
X10 = poly10.fit_transform(x_plot[:,np.newaxis])

fig = plt.figure(figsize=(8, 6))
p1=plt.plot(x_test, y_test, 'o', ms=10, alpha=0.5, label='test data')
p2=plt.plot(x_plot,clf.predict(x_plot[:,np.newaxis]), lw=2, label='linear')
p3=plt.plot(x_plot,clf3.predict(X3), lw=2, label='3rd order')
p10=plt.plot(x_plot,clf10.predict(X10), lw=2, label='10th order')
plt.legend(loc='best')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best')
Title="N=%i, $\sigma=%.2f$"%(N_test,sigma_test)
plt.title(Title+" (pred.)")
plt.tight_layout()
plt.ylim((-6,12))

plt.grid()
plt.show()

# %% [markdown]
# *For $f(x)=2x$, $N_{\mathrm{train}}=10$ and $\sigma=0$ (noiseless case), train the three classes of models (linear, third-order polynomial, and tenth order polynomial) for a training set when $x_i  \in [0,1]$. Make graphs comparing fits for different order of polynomials. Which model fits the data the best?*

# %% [markdown]
#  **Answer:** All of three models (linear, 3rd-order, and 10th-order) fit the data ideally in the same way.

# %% [markdown]
# *Do you think that the data that has the least error on the training set will also make the best predictions? Why or why not? Can you try to discuss and formalize your intuition? What can go right and what can go wrong?*

# %% [markdown]
# **Answer:** I think the data that has the least error on the training set will **"not"** make the best predictions because:
# * the testing data which are out of range of the training data might give us the different manners from the data that we use to train our model
# * and sometimes fitting model from training data can give us the overfitting model which are not good at predicting data with random noise every time we execute the code.

# %% [markdown]
# *Check your answer by seeing how well your fits predict newly generated test data (including on data outside the range you fit on, for example $x \in [0,1.2]$) using the code below. How well do you do on points in the range of $x$ where you trained the model? How about points outside the original training data set?*

# %% [markdown]
# **Answer:** I did not see anything from it because the three models fit the testing data as the same way as they fit the training data. Let us look forward to the next station!

# %% [markdown]
# ## 1.2 $f(x)=2x$, $N_{\mathrm{train}}=10$, $\sigma=1$

# %%
################# Training the Model #################

# The Training Data
N_train=10
sigma_train=1;
x=np.linspace(0,1,N_train)
s = sigma_train*np.random.randn(N_train)
y=2*x+s #linear
fig = plt.figure(figsize=(8, 6))
p1=plt.plot(x, y, "o", ms=8, alpha=0.5, label='Training')

# Linear Regression
clf = linear_model.LinearRegression()
clf.fit(x[:, np.newaxis], y)
xplot=np.linspace(-0.02,1.02,200) # grid of points, some are in the training set, some are not
linear_plot=plt.plot(xplot, clf.predict(xplot[:, np.newaxis]), label='Linear')

# 3rd-order polynomial Regression
poly3 = PolynomialFeatures(degree=3)
X = poly3.fit_transform(x[:,np.newaxis])
clf3 = linear_model.LinearRegression()
clf3.fit(X,y)
Xplot=poly3.fit_transform(xplot[:,np.newaxis])
poly3_plot=plt.plot(xplot, clf3.predict(Xplot), label='Poly 3')

# 10th-order polynomial Regression
poly10 = PolynomialFeatures(degree=10)
X = poly10.fit_transform(x[:,np.newaxis])
clf10 = linear_model.LinearRegression()
clf10.fit(X,y)
Xplot=poly10.fit_transform(xplot[:,np.newaxis])
poly10_plot=plt.plot(xplot, clf10.predict(Xplot), label='Poly 10')

plt.legend(loc='best')
plt.ylim([-5,12])
plt.xlabel("x")
plt.ylabel("y")
Title="N=%i, $\sigma=%.2f$"%(N_train,sigma_train)
plt.title(Title+" (train)")

plt.grid()
plt.show()



################# Testing the Fitted Model #################

# The testing data
N_test=20
sigma_test=sigma_train
max_x=1.2
x_test=max_x*np.random.random(N_test)
s_test = sigma_test*np.random.randn(N_test)
y_test=2*x_test+s_test #Linear

# Make design matrices for prediction : Linear, 3rd and 10th
x_plot=np.linspace(0,max_x, 200)
X3 = poly3.fit_transform(x_plot[:,np.newaxis])
X10 = poly10.fit_transform(x_plot[:,np.newaxis])

fig = plt.figure(figsize=(8, 6))
p1=plt.plot(x_test, y_test, 'o', ms=10, alpha=0.5, label='test data')
p2=plt.plot(x_plot,clf.predict(x_plot[:,np.newaxis]), lw=2, label='linear')
p3=plt.plot(x_plot,clf3.predict(X3), lw=2, label='3rd order')
p10=plt.plot(x_plot,clf10.predict(X10), lw=2, label='10th order')
plt.legend(loc='best')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best')
Title="N=%i, $\sigma=%.2f$"%(N_test,sigma_test)
plt.title(Title+" (pred.)")
plt.tight_layout()
plt.ylim((-10,14))
#plt.xlim((-0.2,1.4))

plt.grid()
plt.show()

# %% [markdown]
# *For $f(x)=2x$, $N_{\mathrm{train}}=10$ and $\sigma=1$, train the three classes of models (linear, third-order polynomial, and tenth order polynomial) for a training set when $x_i  \in [0,1]$. Make graphs comparing fits for different order of polynomials. Which model fits the data the best?*

# %% [markdown]
#  **Answer:** From visual analizing, the 10th-order model fits the training data the best.

# %% [markdown]
# *Do you think that the data that has the least error on the training set will also make the best predictions? Why or why not? Can you try to discuss and formalize your intuition? What can go right and what can go wrong?*

# %% [markdown]
# **Answer:** I insist on my answer in 1.1.

# %% [markdown]
# *Check your answer by seeing how well your fits predict newly generated test data (including on data outside the range you fit on, for example $x \in [0,1.2]$) using the code below. How well do you do on points in the range of $x$ where you trained the model? How about points outside the original training data set?*

# %% [markdown]
# **Answer:** The data in the range of training data set fit the 10th-order model properly. While the data outside the original training data set fit the linear model the best. On the other hand, the 3rd-order model fits wholly testing data (to my eye). It seems weird that our data at different domains (x) give us differently fitted models. In my opinion, I think it is because adding noise in a few numbers of traning data make that mistake to our prediction.

# %% [markdown]
# *Repeat the exercises above for $f(x)=2x$, $N_{\mathrm{train}}=10$, and $\sigma=1$. What changes?*

# %% [markdown]
# **Answer:** The traning/testing data with $\sigma=1$ (noise) in small number of the data make more errors to model-prediction.

# %% [markdown]
# ## 1.3 $f(x)=2x$, $N_{\mathrm{train}}=100$, $\sigma=1$

# %%
################# Training the Model #################

# The Training Data
N_train=100
sigma_train=1;
x=np.linspace(0,1,N_train)
s = sigma_train*np.random.randn(N_train)
y=2*x+s #linear
fig = plt.figure(figsize=(8, 6))
p1=plt.plot(x, y, "o", ms=8, alpha=0.5, label='Training')

# Linear Regression
clf = linear_model.LinearRegression()
clf.fit(x[:, np.newaxis], y)
xplot=np.linspace(-0.02,1.02,200) # grid of points, some are in the training set, some are not
linear_plot=plt.plot(xplot, clf.predict(xplot[:, np.newaxis]), label='Linear')

# 3rd order polynomial Regression
poly3 = PolynomialFeatures(degree=3)
X = poly3.fit_transform(x[:,np.newaxis])
clf3 = linear_model.LinearRegression()
clf3.fit(X,y)
Xplot=poly3.fit_transform(xplot[:,np.newaxis])
poly3_plot=plt.plot(xplot, clf3.predict(Xplot), label='Poly 3')

# 10th order polynomial Regression
poly10 = PolynomialFeatures(degree=10)
X = poly10.fit_transform(x[:,np.newaxis])
clf10 = linear_model.LinearRegression()
clf10.fit(X,y)
Xplot=poly10.fit_transform(xplot[:,np.newaxis])
poly10_plot=plt.plot(xplot, clf10.predict(Xplot), label='Poly 10')

plt.legend(loc='best')
plt.ylim([-7,7])
plt.xlabel("x")
plt.ylabel("y")
Title="N=%i, $\sigma=%.2f$"%(N_train,sigma_train)
plt.title(Title+" (train)")

plt.grid()
plt.show()



################# Testing the Fitted Model #################

# The testing data
N_test=20
sigma_test=sigma_train
max_x=1.2
x_test=max_x*np.random.random(N_test)
s_test = sigma_test*np.random.randn(N_test)
y_test=2*x_test+s_test #Linear

# Make design matrices for prediction : Linear, 3rd and 10th
x_plot=np.linspace(0,max_x, 200)
X3 = poly3.fit_transform(x_plot[:,np.newaxis])
X10 = poly10.fit_transform(x_plot[:,np.newaxis])

fig = plt.figure(figsize=(8, 6))
p1=plt.plot(x_test, y_test, 'o', ms=10, alpha=0.5, label='test data')
p2=plt.plot(x_plot,clf.predict(x_plot[:,np.newaxis]), lw=2, label='linear')
p3=plt.plot(x_plot,clf3.predict(X3), lw=2, label='3rd order')
p10=plt.plot(x_plot,clf10.predict(X10), lw=2, label='10th order')
plt.legend(loc='best')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best')
Title="N=%i, $\sigma=%.2f$"%(N_test,sigma_test)
plt.title(Title+" (pred.)")
plt.tight_layout()
plt.ylim((-6,6))

plt.grid()
plt.show()

# %% [markdown]
# *For $f(x)=2x$, $N_{\mathrm{train}}=100$ and $\sigma=1$ , train the three classes of models (linear, third-order polynomial, and tenth order polynomial) for a training set when $x_i  \in [0,1]$. Make graphs comparing fits for different order of polynomials. Which model fits the data the best?*

# %% [markdown]
#  **Answer:** From visual analizing, the 10th order model fits the training data the best. (Actually it is quite hard to deduce like that from just looking at the graph visually.)

# %% [markdown]
# *Do you think that the data that has the least error on the training set will also make the best predictions? Why or why not? Can you try to discuss and formalize your intuition? What can go right and what can go wrong?*

# %% [markdown]
# **Answer:** I insist on my answer in 1.1.

# %% [markdown]
# *Check your answer by seeing how well your fits predict newly generated test data (including on data outside the range you fit on, for example $x \in [0,1.2]$) using the code below. How well do you do on points in the range of $x$ where you trained the model? How about points outside the original training data set?*

# %% [markdown]
# **Answer:** The linear model fits wholly testing data the best. This make my answer of the question above more reliable.

# %% [markdown]
# *Repeat the exercises above for $f(x)=2x$, $N_{\mathrm{train}}=100$, and $\sigma=1$. What changes?*

# %% [markdown]
# **Answer:** In this case we have adequate numbers of training data, so that those problems in 2.2 are solved and our prediction is more efficient.

# %% [markdown]
# *Summarize what you have learned about the relationship between model complexity (number of parameters), goodness of fit on training data, and the ability to predict well.*

# %% [markdown]
# **Answer:**
# * The more model complexity, the more goodness of fit on training data.
# * The model with more goodness of fit on training data is not necessary to be more goodness of prediction.

# %% [markdown]
# # 2. Fitting vs. predicting when the data is not in the model class

# %% [markdown]
# ## 2.1 $f(x)=2x-10x^5+15x^{10}$, $N_{\mathrm{train}}=10$, $\sigma=0$

# %%
################# Training the Model #################

# The Training Data
N_train=10
sigma_train=0;
x=np.linspace(0,1,N_train)
s = sigma_train*np.random.randn(N_train)
y=2*x-10*x**5+15*x**10+s # Tenth Order
fig = plt.figure(figsize=(8, 6))
p1=plt.plot(x, y, "o", ms=8, alpha=0.5, label='Training')

# Linear Regression
clf = linear_model.LinearRegression()
clf.fit(x[:, np.newaxis], y)
xplot=np.linspace(-0.02,1.02,200) # grid of points, some are in the training set, some are not
linear_plot=plt.plot(xplot, clf.predict(xplot[:, np.newaxis]), label='Linear')

# 3rd order polynomial Regression
poly3 = PolynomialFeatures(degree=3)
X = poly3.fit_transform(x[:,np.newaxis])
clf3 = linear_model.LinearRegression()
clf3.fit(X,y)
Xplot=poly3.fit_transform(xplot[:,np.newaxis])
poly3_plot=plt.plot(xplot, clf3.predict(Xplot), label='Poly 3')

# 10th order polynomial Regression
poly10 = PolynomialFeatures(degree=10)
X = poly10.fit_transform(x[:,np.newaxis])
clf10 = linear_model.LinearRegression()
clf10.fit(X,y)
Xplot=poly10.fit_transform(xplot[:,np.newaxis])
poly10_plot=plt.plot(xplot, clf10.predict(Xplot), label='Poly 10')

plt.legend(loc='best')
plt.ylim([-4,10])
plt.xlabel("x")
plt.ylabel("y")
Title="N=%i, $\sigma=%.2f$"%(N_train,sigma_train)
plt.title(Title+" (train)")

plt.grid()
plt.show()



################# Testing the Fitted Model #################

# The testing data
N_test=20
sigma_test=sigma_train
max_x=1.2
x_test=max_x*np.random.random(N_test)
s_test = sigma_test*np.random.randn(N_test)
y_test=2*x_test-10*x_test**5+15*x_test**10+s_test # Tenth Order

# Make design matrices for prediction : Linear, 3rd and 10th
x_plot=np.linspace(0,max_x, 200)
X3 = poly3.fit_transform(x_plot[:,np.newaxis])
X10 = poly10.fit_transform(x_plot[:,np.newaxis])

fig = plt.figure(figsize=(8, 6))
p1=plt.plot(x_test, y_test, 'o', ms=10, alpha=0.5, label='test data')
p2=plt.plot(x_plot,clf.predict(x_plot[:,np.newaxis]), lw=2, label='linear')
p3=plt.plot(x_plot,clf3.predict(X3), lw=2, label='3rd order')
p10=plt.plot(x_plot,clf10.predict(X10), lw=2, label='10th order')
plt.legend(loc='best')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best')
Title="N=%i, $\sigma=%.2f$"%(N_test,sigma_test)
plt.title(Title+" (pred.)")
plt.tight_layout()
plt.ylim((-2.5,60))
plt.xlim((-0.2,1.4))

plt.grid()
plt.show()

# %% [markdown]
# *Record your observations.*

# %% [markdown]
# **Answer:** The 10th-order model can fit the training and testing data perfectly because we use 10th-order  function to generate those data without any noise. Not surprised.

# %% [markdown]
# ## 2.2 $f(x)=2x-10x^5+15x^{10}$, $N_{\mathrm{train}}=10$, $\sigma=1$

# %%
################# Training the Model #################

# The Training Data
N_train=10
sigma_train=1;
x=np.linspace(0,1,N_train)
s = sigma_train*np.random.randn(N_train)
y=2*x-10*x**5+15*x**10+s # Tenth Order
fig = plt.figure(figsize=(8, 6))
p1=plt.plot(x, y, "o", ms=8, alpha=0.5, label='Training')

# Linear Regression
clf = linear_model.LinearRegression()
clf.fit(x[:, np.newaxis], y)
xplot=np.linspace(-0.02,1.02,200) # grid of points, some are in the training set, some are not
linear_plot=plt.plot(xplot, clf.predict(xplot[:, np.newaxis]), label='Linear')

# 3rd order polynomial Regression
poly3 = PolynomialFeatures(degree=3)
X = poly3.fit_transform(x[:,np.newaxis])
clf3 = linear_model.LinearRegression()
clf3.fit(X,y)
Xplot=poly3.fit_transform(xplot[:,np.newaxis])
poly3_plot=plt.plot(xplot, clf3.predict(Xplot), label='Poly 3')

# 10th order polynomial Regression
poly10 = PolynomialFeatures(degree=10)
X = poly10.fit_transform(x[:,np.newaxis])
clf10 = linear_model.LinearRegression()
clf10.fit(X,y)
Xplot=poly10.fit_transform(xplot[:,np.newaxis])
poly10_plot=plt.plot(xplot, clf10.predict(Xplot), label='Poly 10')

plt.legend(loc='best')
plt.ylim([-6,12])
plt.xlabel("x")
plt.ylabel("y")
Title="N=%i, $\sigma=%.2f$"%(N_train,sigma_train)
plt.title(Title+" (train)")

plt.grid()
plt.show()



################# Testing the Fitted Model #################

# The testing data
N_test=20
sigma_test=sigma_train
max_x=1.2
x_test=max_x*np.random.random(N_test)
s_test = sigma_test*np.random.randn(N_test)
y_test=2*x_test-10*x_test**5+15*x_test**10+s_test # Tenth Order

# Make design matrices for prediction : Linear, 3rd and 10th
x_plot=np.linspace(0,max_x, 200)
X3 = poly3.fit_transform(x_plot[:,np.newaxis])
X10 = poly10.fit_transform(x_plot[:,np.newaxis])

fig = plt.figure(figsize=(8, 6))
p1=plt.plot(x_test, y_test, 'o', ms=10, alpha=0.5, label='test data')
p2=plt.plot(x_plot,clf.predict(x_plot[:,np.newaxis]), lw=2, label='linear')
p3=plt.plot(x_plot,clf3.predict(X3), lw=2, label='3rd order')
p10=plt.plot(x_plot,clf10.predict(X10), lw=2, label='10th order')
plt.legend(loc='best')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best')
Title="N=%i, $\sigma=%.2f$"%(N_test,sigma_test)
plt.title(Title+" (pred.)")
plt.tight_layout()
plt.ylim((-10,80))
plt.xlim((-0.2,1.4))

plt.grid()
plt.show()

# %% [markdown]
# *Record your observations.*

# %% [markdown]
# **Answer:** Despite adding (Gaussian) noise in the training/testing data, the 10th-order model is the best model anyway. Moreover, looking at the train graph, the 10th-order model seems overfitted with our data which I think that this problem results from the lack of adequate numbers of training data. Furthermore, the data which are much more out of range of the training data make more errors - the differences of the predictions and the true values.

# %% [markdown]
# ## 2.3 $f(x)=2x-10x^5+15x^{10}$, $N_{\mathrm{train}}=100$, $\sigma=1$

# %%
################# Training the Model #################

# The Training Data
N_train=100
sigma_train=1;
x=np.linspace(0,1,N_train)
s = sigma_train*np.random.randn(N_train)
y=2*x-10*x**5+15*x**10+s # Tenth Order
fig = plt.figure(figsize=(8, 6))
p1=plt.plot(x, y, "o", ms=8, alpha=0.5, label='Training')

# Linear Regression
clf = linear_model.LinearRegression()
clf.fit(x[:, np.newaxis], y)
xplot=np.linspace(-0.02,1.02,200) # grid of points, some are in the training set, some are not
linear_plot=plt.plot(xplot, clf.predict(xplot[:, np.newaxis]), label='Linear')

# 3rd order polynomial Regression
poly3 = PolynomialFeatures(degree=3)
X = poly3.fit_transform(x[:,np.newaxis])
clf3 = linear_model.LinearRegression()
clf3.fit(X,y)
Xplot=poly3.fit_transform(xplot[:,np.newaxis])
poly3_plot=plt.plot(xplot, clf3.predict(Xplot), label='Poly 3')

# 10th order polynomial Regression
poly10 = PolynomialFeatures(degree=10)
X = poly10.fit_transform(x[:,np.newaxis])
clf10 = linear_model.LinearRegression()
clf10.fit(X,y)
Xplot=poly10.fit_transform(xplot[:,np.newaxis])
poly10_plot=plt.plot(xplot, clf10.predict(Xplot), label='Poly 10')

plt.legend(loc='best')
plt.ylim([-7,9])
plt.xlabel("x")
plt.ylabel("y")
Title="N=%i, $\sigma=%.2f$"%(N_train,sigma_train)
plt.title(Title+" (train)")

plt.grid()
plt.show()



################# Testing the Fitted Model #################

# The testing data
N_test=20
sigma_test=sigma_train
max_x=1.2
x_test=max_x*np.random.random(N_test)
s_test = sigma_test*np.random.randn(N_test)
y_test=2*x_test-10*x_test**5+15*x_test**10+s_test # Tenth Order

# Make design matrices for prediction : Linear, 3rd and 10th
x_plot=np.linspace(0,max_x, 200)
X3 = poly3.fit_transform(x_plot[:,np.newaxis])
X10 = poly10.fit_transform(x_plot[:,np.newaxis])

fig = plt.figure(figsize=(8, 6))
p1=plt.plot(x_test, y_test, 'o', ms=10, alpha=0.5, label='test data')
p2=plt.plot(x_plot,clf.predict(x_plot[:,np.newaxis]), lw=2, label='linear')
p3=plt.plot(x_plot,clf3.predict(X3), lw=2, label='3rd order')
p10=plt.plot(x_plot,clf10.predict(X10), lw=2, label='10th order')
plt.legend(loc='best')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best')
Title="N=%i, $\sigma=%.2f$"%(N_test,sigma_test)
plt.title(Title+" (pred.)")
plt.tight_layout()
plt.ylim((-15,100))
plt.xlim((-0.2,1.4))

plt.grid()
plt.show()

# %% [markdown]
# *Record your observations.*

# %% [markdown]
# **Answer:** According to 2.2, when a number of our data are added enough, the 10th-order model is still the best model but the overfitting problem is ejected. However, the data which are much more out of range of the training data make more errors as the same way in 2.2.

# %% [markdown]
# *Do better fits lead to better predictions?*

# %% [markdown]
# **Answer:** In this case, the generating function is the 10th-order function and we have only three (linear, 3rd-order, 10th-order) models to fit our data, we can say that "better fits lead to better predictions". On the flip side, the cases that other models used to fit our data ard provided especially the models which are more than 10th-order polynomial, These might make the testing data which are out of range of the training data be better predictions than the ones give us the better fits. Let us say I still insist on my answer in 1.1.

# %% [markdown]
# *What is the relationship between the true model for generating the data and the model class that has the most predictive power? How is this related to the model complexity? How does this depend on the number of data points $N_{\mathrm{train}}$ and $\sigma$?*

# %% [markdown]
# **Answer:**
# * The model class that has the most predictive power tends to be the best model used to represent the generating function.
# * The more model complexity, the more predictive power. It is because we use more parameters, in other words, more complexity to describe the model with more predictive power.
# * The number of data points make our fitted model reliable and it can also solve overfitting problems. While $\sigma$ makes our data hard to fit well with a model. (I did not think I understand this question properly.)

# %% [markdown]
# *Summarize what you think you learned about the relationship of knowing the true model class and predictive power.*

# %% [markdown]
# **Answer:**
# * Knowing the true model class make us get the fittest predictive power easily.
# * The polynomial model which have lower order with respect to the true model class cannot be the fittest model.
